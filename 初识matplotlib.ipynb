# %% [markdown]
# ### 标题用法

# %% [markdown]
# ##### 导入matplotlib包中的pyplot模块as别名

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
x=np.arange(-50,51) #选取-50到50的数字

# %%
y=x**2

# %%
plt.title('y=x**2') #表格名称
plt.plot(x,y) #绘制线性图
